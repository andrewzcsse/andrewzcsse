# %% [markdown]
# ---
# title: Andrew Zaletski Individual Review
# description: My findings and what I learned through our group project in trimester 1.
# layout: post
# toc: true
# type: tangibles
# comments: true
# courses: {compsci: {week: 11}}
# ---

# %% [markdown]
# ## Aspects of OOP
# - Using code to design our project based around "objects" rather than functions
# - OOP was really helpful in how we used the advantages offered to give our game a unique structure
#
# # Applications of OOP in our project
# - OOP was necessary as we had many objects that required defining and giving their own characteristics
#     - Sprite
#     - Hitboxes
#     - Collider zones

# %%
# %%js
#
# // Names the class
# class Lopez {
#         constructor() {
#             // Listing out all of the characteristics of the Lopez class
#             this.image = document.getElementById("lopezSprite");
#             this.x = START_X;
#             this.y = START_Y;
#             this.width = SPRITE_WIDTH*SCALE_FACTOR
#             this.height = SPRITE_HEIGHT*SCALE_FACTOR
#             this.minFrame = 0;
#             this.maxFrame = FRAME_LIMIT -1;
#             this.frameX = 0;
#             this.frameY = 0;
#             this.currentDirection = 'down';
#         }
#
#         // Allows the Lopes scale factor to change for each screen
#         resize() {
#             this.width = SPRITE_WIDTH*backgroundImage.playerScaleFactor
#             this.height = SPRITE_HEIGHT*backgroundImage.playerScaleFactor
#         }
#         draw(context) {
#             context.drawImage(
#                 this.image,
#                 this.frameX * SPRITE_WIDTH,
#                 this.frameY * SPRITE_HEIGHT,
#                 SPRITE_WIDTH,
#                 SPRITE_HEIGHT,
#                 this.x,
#                 this.y,
#                 this.width,
#                 this.height
#             );
#         }
#         // update frameX of object
#         updateFrame() {
#             if (this.frameX < this.maxFrame) {
#                 this.frameX++;
#             } else {
#                 this.frameX = 0;
#             }
#         }
#     }

# %% [markdown]
# # Classes
# - Classes were a key part of implementation for us as seen above
# - Classes were used to characterize both the sprite and, more importantly, our hitboxes and collider zones

# %%
# %%js
#
# // Show that ColliderZone extends the existing DivElement parent class
# class ColliderZone extends HTMLDivElement {
#     static observedAttributes = ["width", "height", "x", "y"]
#     constructor() {
#         super()
#         // Sets up the specific feature that differentiates ColliderZone
#         if (!this.getAttribute("width") || !this.getAttribute("height") || !this.getAttribute("x") || !this.getAttribute("y") || !this.getAttribute("newBackground") || !this.getAttribute("newX") || !this.getAttribute("newY")) {
#             throw new Error("Needs required attributes (height, width, x, y, newX, and newY)")
#         }
#         this.height = Number(this.getAttribute("height"))
#         this.width = Number(this.getAttribute("width"))
#         this.x = Number(this.getAttribute("x"))
#         this.y =  Number(this.getAttribute("y"))
#         this.newBackground = this.getAttribute("newBackground")
#         this.style.backgroundColor = 'red'
#         this.newX = this.getAttribute("newX")
#         this.newY = this.getAttribute("newY")
#         this.isActive = false;
#     }
#
#     // The functionality assigned to ColliderZone that will change the background``
#     isColliding(player) {
#         if (
#             player.x + (player.width) >= this.x && //left
#             player.x <= this.x + this.width && //right
#             player.y + (player.height) >= this.y && //top
#             player.y <= this.y + this.height //bottom
#         ) {
#             return true
#         }
#         return false
#     }
#     draw (context) {
#             context.fillStyle = 'blue'
#             context.fillRect(
#                 this.x,
#                 this.y,
#                 this.width,
#                 this.height
#             );
#         }
# }

# %% [markdown]
# ## If Statements
#
# # Application of If Statements in Our Project
# - If statements were crucial to our implementation of the various functions in our project
#     - Changing backgrounds

# %%
# %%js
#
# // Checks for the position of the sprite to see if it is actively hitting a collider zone
# if (!this.getAttribute("width") || !this.getAttribute("height") || !this.getAttribute("x") || !this.getAttribute("y") || !this.getAttribute("newBackground") || !this.getAttribute("newX") || !this.getAttribute("newY")) {
#         throw new Error("Needs required attributes (height, width, x, y, newX, and newY)")
#     }
#     this.height = Number(this.getAttribute("height"))
#     this.width = Number(this.getAttribute("width"))
#     this.x = Number(this.getAttribute("x"))
#     this.y =  Number(this.getAttribute("y"))
#     this.newBackground = this.getAttribute("newBackground")
#     this.style.backgroundColor = 'red'
#     this.newX = this.getAttribute("newX")
#     this.newY = this.getAttribute("newY")
#     this.isActive = false;
#
# // Returns true or false depending on what the above code returrns
# isColliding(player) {
#     if (
#         player.x + (player.width) >= this.x && //left
#         player.x <= this.x + this.width && //right
#         player.y + (player.height) >= this.y && //top
#         player.y <= this.y + this.height //bottom
#     ) {
#         return true
#     }
#         return false
# }
#
# // Drawing the new canvas
# draw (context) {
#         context.fillStyle = 'blue'
#         context.fillRect(
#             this.x,
#             this.y,
#             this.width,
#             this.height
#         );
#     }

# %% [markdown]
# ## Importance of Team Planning
#
# # Github Issues
# - We didn't initially use issues to our advantage
#     - As we started to assign issues to individuals as needed, our work process was a lot more streamlined since everyone could fixate on what was assigned to them and we could reconvene when necessary
#
# # Working Collaboratively
# - While we did place heavy emphasis on figuring out our individual tasks, working together was essential throughout the development process
#     - We realized that we don't always have the answers, so sometimes we would have to put our heads together and problem-solve
#
# # Making Weekly Plans
# - Having structure to each week adn goal-setting was also a key component of the way that we worked
# - In each weekly plan that went into a notebook, I would ask everybody for their goals for that week so that they could always check the time box and visualize what they wanted to accomplish for that week
